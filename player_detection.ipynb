# %%
from roboflow import Roboflow
rf = Roboflow(api_key="FELNRy9TadmLCfq2bNbH")
project = rf.workspace("university-zjdmp").project("player-detection-for-tcmr")
version = project.version(1)
dataset = version.download("yolov7")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Player-Detection-for-TCMR-1 in yolov7pytorch:: 100%|██████████| 4902/4902 [00:03<00:00, 1258.66it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt source= Player-Detection-for-TCMR-1/data.yaml epochs=20
# Out:
# ...
#
#   0%|          | 0.00/21.5M [00:00<?, ?B/s]
#   2%|▏         | 456k/21.5M [00:00<00:04, 4.51MB/s]
#   4%|▍         | 904k/21.5M [00:00<00:08, 2.63MB/s]
#   5%|▌         | 1.18M/21.5M [00:00<00:09, 2.29MB/s]
#  10%|█         | 2.20M/21.5M [00:00<00:04, 4.56MB/s]
#  13%|█▎        | 2.73M/21.5M [00:00<00:04, 3.99MB/s]
#  17%|█▋        | 3.65M/21.5M [00:01<00:04, 3.98MB/s]
#  21%|██        | 4.52M/21.5M [00:01<00:04, 4.14MB/s]
#  26%|██▌       | 5.60M/21.5M [00:01<00:03, 5.53MB/s]
#  29%|██▉       | 6.23M/21.5M [00:01<00:03, 4.92MB/s]
#  34%|███▎      | 7.24M/21.5M [00:01<00:03, 4.64MB/s]
#  37%|███▋      | 8.01M/21.5M [00:01<00:03, 4.42MB/s]
#  43%|████▎     | 9.29M/21.5M [00:02<00:02, 6.05MB/s]
#  46%|████▋     | 10.0M/21.5M [00:02<00:02, 5.35MB/s]
#  51%|█████     | 11.0M/21.5M [00:02<00:02, 5.31MB/s]
#  58%|█████▊    | 12.5M/21.5M [00:02<00:01, 7.30MB/s]
#  62%|██████▏   | 13.4M/21.5M [00:02<00:01, 6.34MB/s]
#  66%|██████▌   | 14.1M/21.5M [00:02<00:01, 5.41MB/s]
# ...

# %%
from ultralytics import YOLO

model = YOLO("model/last.pt")
model.predict("input_video/new_out.avi", conf = 0.8 ,save =True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/214) d:\haCKATHON\utils\input_video\new_out.avi: 480x640 1 person, 315.0ms
# video 1/1 (2/214) d:\haCKATHON\utils\input_video\new_out.avi: 480x640 1 person, 301.6ms
# video 1/1 (3/214) d:\haCKATHON\utils\input_video\new_out.avi: 480x640 1 person, 257.5ms
# video 1/1 (4/214) d:\haCKATHON\utils\input_video\new_out.avi: 480x640 1 person, 263.0ms
# ...
